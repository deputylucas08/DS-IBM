# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 10.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (pyproject.toml) ... done
#   Created wheel for sqlalchemy: filename=sqlalchemy-1.3.9-cp310-cp310-macosx_10_9_universal2.whl size=1143019 sha256=d0eb4816833ef7a1fb8fca4e7e4e42849d97b8127c41fe367b5293e191497dc3
#   Stored in directory: /Users/lukaszlaskowski/Library/Caches/pip/wheels/8b/6d/9c/e1793e5a2d85b89b8c362a4f0e3def54b786bcd14923b9ff00
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.37
#     Uninstalling SQLAlchemy-2.0.37:
#       Successfully uninstalled SQLAlchemy-2.0.37
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.9 which is incompatible.
# Successfully installed sqlalchemy-1.3.9
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install ipython-sql
# !pip install ipython-sql prettytable
# Out:
# Requirement already satisfied: ipython-sql in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython-sql) (8.5.0)
# Collecting sqlalchemy>=2.0 (from ipython-sql)
#   Downloading sqlalchemy-2.0.40-cp310-cp310-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: sqlparse in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: backcall in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (2.13.0)
# Requirement already satisfied: stack-data in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.5.0)
# Requirement already satisfied: traitlets>=5 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (5.4.0)
# Requirement already satisfied: pexpect>4.3 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: appnope in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: wcwidth in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython->ipython-sql) (1.0.0)
# Requirement already satisfied: asttokens in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython->ipython-sql) (2.0.8)
# Requirement already satisfied: pure-eval in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Downloading sqlalchemy-2.0.40-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# Successfully installed sqlalchemy-2.0.40
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipython-sql in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.12.0)
# Requirement already satisfied: ipython in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython-sql) (8.5.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipython-sql) (2.0.40)
# Requirement already satisfied: sqlparse in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from prettytable) (0.2.5)
# Requirement already satisfied: greenlet>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: backcall in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (2.13.0)
# Requirement already satisfied: stack-data in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.5.0)
# Requirement already satisfied: traitlets>=5 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (5.4.0)
# Requirement already satisfied: pexpect>4.3 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: appnope in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython->ipython-sql) (1.0.0)
# Requirement already satisfied: asttokens in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython->ipython-sql) (2.0.8)
# Requirement already satisfied: pure-eval in /Users/lukaszlaskowski/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df=pd.read_csv('/Users/lukaszlaskowski/Desktop/IBM_DS_R/Project 7 Capstone/Spacex.csv')
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
#DROP THE TABLE IF EXISTS

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql PRAGMA table_info(SPACEXTABLE);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(0, 'Date', 'TEXT', 0, None, 0),
#  (1, 'Time (UTC)', 'TEXT', 0, None, 0),
#  (2, 'Booster_Version', 'TEXT', 0, None, 0),
#  (3, 'Launch_Site', 'TEXT', 0, None, 0),
#  (4, 'Payload', 'TEXT', 0, None, 0),
#  (5, 'PAYLOAD_MASS__KG_', 'INT', 0, None, 0),
#  (6, 'Orbit', 'TEXT', 0, None, 0),
#  (7, 'Customer', 'TEXT', 0, None, 0),
#  (8, 'Mission_Outcome', 'TEXT', 0, None, 0),
#  (9, 'Landing_Outcome', 'TEXT', 0, None, 0)]

# %%
# %sql SELECT DISTINCT Launch_Site FROM SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql SELECT * FROM SPACEXTABLE WHERE Launch_Site LIKE 'CCA%' LIMIT 5
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-12-08', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-10-08', '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-03-01', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %%
# %sql select distinct landing_outcome from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (parachute)',),
#  ('No attempt',),
#  ('Uncontrolled (ocean)',),
#  ('Controlled (ocean)',),
#  ('Failure (drone ship)',),
#  ('Precluded (drone ship)',),
#  ('Success (ground pad)',),
#  ('Success (drone ship)',),
#  ('Success',),
#  ('Failure',),
#  ('No attempt ',)]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select sum(PAYLOAD_MASS__KG_) as Total_Payload_Mass_Kg FROM SPACEXTABLE where Customer = 'NASA (CRS)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(45596,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select ROUND(AVG(PAYLOAD_MASS__KG_),2) as Average_Payload_Mass_Kg FROM SPACEXTABLE where Booster_Version LIKE 'F9 v1.1%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2534.67,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %sql select MIN(Date) FROM SPACEXTABLE where Landing_Outcome = 'Success'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2018-07-22',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql select Booster_Version FROM SPACEXTABLE where PAYLOAD_MASS__KG_ between 4000 and 6000
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 v1.1',),
#  ('F9 v1.1 B1011',),
#  ('F9 v1.1 B1014',),
#  ('F9 v1.1 B1016',),
#  ('F9 FT B1020',),
#  ('F9 FT B1022',),
#  ('F9 FT B1026',),
#  ('F9 FT B1030',),
#  ('F9 FT  B1021.2',),
#  ('F9 FT B1032.1',),
#  ('F9 B4 B1040.1',),
#  ('F9 FT  B1031.2',),
#  ('F9 B4 B1043.1',),
#  ('F9 FT  B1032.2',),
#  ('F9 B4  B1040.2',),
#  ('F9 B5 B1046.2',),
#  ('F9 B5 B1047.2',),
#  ('F9 B5 B1046.3',),
#  ('F9 B5B1054',),
#  ('F9 B5 B1048.3',),
#  ('F9 B5 B1051.2 ',),
#  ('F9 B5B1060.1',),
#  ('F9 B5 B1058.2 ',),
#  ('F9 B5B1062.1',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql SELECT COUNT(CASE WHEN Mission_Outcome = 'Success' THEN 1 END) AS Count_Mission_Success, COUNT(CASE WHEN Mission_Outcome like 'Failure%' THEN 1 END) AS Count_Mission_Failure FROM SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(98, 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List all the booster_versions that have carried the maximum payload mass. Use a subquery.

# %%
# %sql SELECT Booster_Version FROM SPACEXTABLE WHERE PAYLOAD_MASS__KG_ = (SELECT MAX(PAYLOAD_MASS__KG_) FROM SPACEXTABLE)
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7 ',)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
# %sql SELECT CASE WHEN substr(Date, 0, 5) = '2015' AND substr(Date, 6, 2) IS NOT NULL THEN CASE WHEN Landing_Outcome = 'Failure (drone ship)' THEN 'Failure Landing in Drone Ship' ELSE NULL END END AS Failure_Landing_Outcome, substr(Date, 6, 2) AS Month, Booster_Version, Launch_Site FROM SPACEXTABLE WHERE substr(Date, 0, 5) = '2015' AND Landing_Outcome = 'Failure (drone ship)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure Landing in Drone Ship', '01', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('Failure Landing in Drone Ship', '04', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# %sql SELECT Landing_Outcome, COUNT(*) AS Count_Landing_Outcome FROM SPACEXTABLE WHERE Date BETWEEN '2010-06-04' AND '2017-03-20' GROUP BY Landing_Outcome ORDER BY Count_Landing_Outcome DESC
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1)]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# <!--
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2024-07-10 | 1.1 |Anita Verma | Changed Version|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |
# -->

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
